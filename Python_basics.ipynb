# %% [markdown]
# <a href="https://colab.research.google.com/github/ajmalqureshi029/ajmal-qureshi/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ajmal=28
ajmal
# Out:
# 28

# %%
ariba=25
ariba
# Out:
# 25

# %%
del print
print(ajmal+ariba)
# Out:
# 53
