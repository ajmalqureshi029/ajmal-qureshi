# %%
ajmal=28
ajmal
# Out:
# 28

# %%
ariba=25
ariba
# Out:
# 25

# %%
del print
print(ajmal+ariba)
# Out:
# 53

# %%
# Write your code for Exercise 1 here!

num1= 10

# %%
num2= 25
sum_of_nums =num1+num2
print(sum_of_nums)
# Out:
# 35

# %%
# Write your code for Exercise 2 here!
